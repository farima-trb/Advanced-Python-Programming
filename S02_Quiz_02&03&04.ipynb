# %% [markdown]
# <a href="https://colab.research.google.com/github/farima-trb/Advanced-Python-Programming/blob/main/S02_Quiz_02%2603%2604.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Quiz 02

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
# Quiz 03

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
class maktabkhooneh:

    def _init_(self, name, age):

        self.name = name

        self.age = age

    def get_name(self):

        print ("my name is %s and my age is %i" % (self.name,self.age))



Maktabkhooneh = maktabkhooneh('maktabkhooneh',7)

Maktabkhooneh.get_name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-480f60afa80f> in <cell line: 15>()
#      13
#      14
# ---> 15 Maktabkhooneh = maktabkhooneh('maktabkhooneh',7)
#      16
#      17 Maktabkhooneh.get_name()
#
# TypeError: maktabkhooneh() takes no arguments

# %%
# output --> TypeError: maktabkhooneh() takes no arguments --> problem in defining the __init__ function name (_init_ instead of __init__)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
class university:
    def __init__(student, name, number_of_grade, grade1, grade2, grade3):
        student.name = name
        student.number_of_grade = number_of_grade
        student.grade1 = grade1
        student.grade2 = grade2
        student.grade3 = grade3

    def get_name(student):
        print("Student name is %s" % student.name)

    def get_grades(student):
        total_grade = student.grade1+student.grade2+student.grade3
        average = total_grade/student.number_of_grade
        print ("The Average is %i" % average)

Information = university("Hossein",3,16,12,18)
Information.get_name()
Information.get_grades()
# Out:
# Student name is Hossein
# The Average is 15

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %%
color = input()
class Vehicle:
    def __init__(model, name, color):
        model.name = name
        model.color = color

    def get_name(model):
        print("Vehicle name is %s" % model.name)

    def get_color(model):
        print("Vehicle color is %s" % model.color)

Information = Vehicle("Hossein",color)
Information.get_name()
Information.get_color()
# Out:
# red
# Vehicle name is Hossein
# Vehicle color is red

# %% [markdown]
# ![32.png](data:image/png;base64,...)

# %%
class Vehicle:
    color = input()
    def __init__(model, name, color):
        model.name = name
        model.color = color

    def get_name(model):
        print("Vehicle name is %s" % model.name)

    def get_color(model):
        print("Vehicle color is %s" % model.color)

Information = Vehicle("Hossein",color)
Information.get_name()
Information.get_color()

# %%
# output --> name 'color' is not defined

# %% [markdown]
# ![33.png](data:image/png;base64,...)

# %%
class Vehicle:
    def __init__(model, name):
        model.name = name

    def get_name(model):
        print("Vehicle name is %s" % model.name)

    def get_color(model):
        color = input()
        print("Vehicle color is %s" % color)

Information = Vehicle("Hossein")
Information.get_name()
Information.get_color()
# Out:
# Vehicle name is Hossein
# red
# Vehicle color is red

# %% [markdown]
# ![34.png](data:image/png;base64,...)

# %%
color = input()

class Vehicle:
    def __init__(model, name):
        model.name = name

    def get_name(model):
        print("Vehicle name is %s" % model.name)

    def get_color(model):
        print("Vehicle color is %s" % color)

Information = Vehicle("Hossein")
Information.get_name()
Information.get_color()
# Out:
# red
# Vehicle name is Hossein
# Vehicle color is red

# %%
# Quiz 04

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
class mobile:
    def __init__(self, name, brand):
        self.name = name
        self.brand = brand

    def get_name(self):
        return self.name

class cpu(mobile):
    def get_name(self):
        print("This mobile has HighTech %s CPU " % self.name)


brand = cpu("Intel","Sony")
print(brand.get_name())
# Out:
# This mobile has HighTech Intel CPU
# None

# %%
# cause we have two print methods in tandem (the first one in the main body and the second one in the class cpu definition) :
# print(print(brand.get_name()) --> This mobile has HighTech Intel CPU
#                                   None

#like print(print(31)) --> 31
#                          None

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %%
class maktabkhooneh:
    def __init__(self, name, grade, age):
        self.name = name
        self.grade = grade
        self.age = age

    def value(self):
        return self.name + self.grade

person = maktabkhooneh("Ahmad","Master",24)
print(person.value())
# Out:
# AhmadMaster
