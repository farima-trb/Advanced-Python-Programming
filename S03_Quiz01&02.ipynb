# %% [markdown]
# <a href="https://colab.research.google.com/github/farima-trb/Advanced-Python-Programming/blob/main/S03_Quiz01%2602.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Quiz 01

# %% [markdown]
# ![Screen Shot 2023-09-14 at 13.03.34.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-14 at 13.03.44.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-14 at 13.03.53.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-14 at 13.04.08.png](data:image/png;base64,...)

# %%
# Quiz 02

# %% [markdown]
# ![Screen Shot 2023-09-17 at 18.29.04.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-17 at 18.29.17.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-17 at 18.29.25.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-17 at 18.29.34.png](data:image/png;base64,...)
