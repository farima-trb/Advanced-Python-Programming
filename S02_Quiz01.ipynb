# %% [markdown]
# <a href="https://colab.research.google.com/github/farima-trb/Python-Programming-Advanced-/blob/main/S02_Quiz01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
array = [(1,4,5), (3,2,7), (8,3,6), (9,2,3)]
array.sort(key = lambda a:a[2])
print(array)
# Out:
# [(9, 2, 3), (1, 4, 5), (8, 3, 6), (3, 2, 7)]

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
mylist = [2,3,5,8,11,14,17,102,44]
print(list(map(lambda x:'Yes' if  x%2==1 else 'No',mylist)))
# Out:
# ['No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No']

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %%
# 1
mylist = [2,15,26,8,11,14,17,102,44]
map_list = map(lambda x:x%10,mylist)
filter_list = list(filter(lambda x: x<=4,map_list))
print(filter_list)
# Out:
# [2, 1, 4, 2, 4]

# %%
# 2
mylist = [2,15,26,8,11,14,17,102,44]
map_list = list(map(lambda x:x%10,mylist))
filter_list = filter(lambda x: x<=4,map_list)
print(filter_list)
# Out:
# <filter object at 0x787c5fbb8700>

# %%
# 3
mylist = [2,15,26,8,11,14,17,102,44]
map_list = list(map(lambda x:x%10,mylist))
filter_list = list(filter(lambda x: x<=4,map_list))
print(filter_list)
# Out:
# [2, 1, 4, 2, 4]

# %%
# 4
mylist = [2,15,26,8,11,14,17,102,44]
map_list = list(map(lambda x:x%5,mylist))
filter_list = list(filter(lambda x: x<4,map_list))
print(filter_list)
# Out:
# [2, 0, 1, 3, 1, 2, 2]

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %%
mylist = ['yellow', 'red', 'blue','red','yellow','red','blue','purple']
mylist.sort()
mylist = list(map(lambda x: 'color' if x=='red' else x,mylist))
output = list(filter(lambda x: x=='red',mylist))
print(output)
# Out:
# []
