# %% [markdown]
# <a href="https://colab.research.google.com/github/farima-trb/Advanced-Python-Programming/blob/main/S05Quiz01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen Shot 2023-10-15 at 14.41.16.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-10-15 at 14.41.22.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-10-15 at 14.41.36.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-10-15 at 14.41.44.png](data:image/png;base64,...)
